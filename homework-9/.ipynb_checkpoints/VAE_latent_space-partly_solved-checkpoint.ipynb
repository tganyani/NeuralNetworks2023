# %% [markdown]
# ### Домашнее задание - Латентное пространство в VAE автоенкодере

# %% [markdown]
# Лучше всего читать оригинальные работы - обычно они очень хорошо и подробно написаны.
# Рекомендую прочитать оригинальную статью [Variational AutoEncoder](https://arxiv.org/pdf/1312.6114.pdf) (VAE, D.P. Kingma et. al., 2013)

# %% [markdown]
# В данном задании необходимо:
#
# 1. Реализовать обычный автоенкодер и VAE автоенкодер с архитектурой как на рисунке:
# <img src='images/mnist_vae.png' width=300>
#
# 2. Обучить его на обучающей выборке из базы данных MNIST и после этого, воспользоваться энкодером, чтобы преобразовать картинки из тестовой выборки в латентное пространство, получить рисунок похожий на рисунок ниже для обоих автоенкодеров и сравнить результаты:
# <img src='images/vae_mnist_cloud.png' width=300>
#
# 3. Построить в латентном пространстве на квадрате [-2, 2]x[-2, 2] сетку из 15x15 значений и построить с помощью декодера картинки цифр для каждого значения из этой сетки и получить рисунок похожий на рисунок ниже:
# <img src='images/vae_mnist_digits.png' width=300>
#
# 4. (*) Скачать датасет со знаменитостями [celebA](https://www.kaggle.com/datasets/jessicali9530/celeba-dataset) и повторить для него, предварительно (если нужно) сократив размеры картинок, чтобы ускорить работу. Поэкспериментировать с модификацией изображений лиц - например, добавляя очки или изменяя цвет волос.
# <img src='images/celeA_intro.png' width=300>

# %% [markdown]
# **Замечание** Для того, чтобы реализовать VAE, прочитайте данную ниже небольшаую теоретическую справку и выполните задание в конце.

# %% [markdown]
# ### Кроссэнтропия
# В теории информации перекрёстная энтропия (или *кроссэнтропия*) между двумя распределениями вероятностей измеряет среднее число бит, необходимых для опознания события из набора возможностей, если используемая схема кодирования базируется на заданном распределении вероятностей $q$, вместо «истинного» распределения $p$.
# Кроссэнтропией распределения $q$ по отношению к распределению $p$ называется величина:
# $$H(p, q) \stackrel{\mathrm{df}}{\;=\;} \mathrm{E}_p[-\log q] = -\sum_x p(x)\, \log q(x) = H(p) + D_{KL}(p \| q),$$
# <!-- или  $$H(p, q) = -\int\limits_X p(x)\, \log q(x)\, dx.$$ -->
# где $H(p)$ - энтропия распределения $p$, $D_{KL}(p \| q)$ - дивергенция Кульбака-Лейблера. Можно показать, что энтропия $H(p)$ всегда меньше чем кроссэнтропия $H(p, q)$. Таким образом, дивергенция Кульбака-Лейблера - неотрицательная величина.

# %% [markdown]
# ### Дивергенция Кульбака-Лейблера
# Расхождение (дивергенция) Ку́льбака-Ле́йблера (англ. Kullback–Leibler divergence), РКЛ, — информационное расхождение, различающая информация, информационный выигрыш, относительная энтропия (англ. relative entropy). Это неотрицательнозначный функционал, являющийся несимметричной мерой удалённости друг от друга двух вероятностных распределений $p$ и $q$, определённых на общем пространстве элементарных событий:
# $$D_{\mathrm{KL}}(p\parallel q) = \sum_x p(x) \, \log \frac{p(x)}{q(x)} \,$$

# %% [markdown]
# ### Дивергенция Кульбака-Лейблера для многомерного нормального распределения
# Допустим, что мы имеем два многомерных нормальных распределения, со средними $\mu_0, \mu_1$ и с (обратимыми) матрицами ковариаций $\Sigma_0, \Sigma_1$. Если два распределения имеют одинаковую размерность $k$, то РКЛ между распределениями следующее:
# $$D_\text{KL}(\mathcal{N}_0 \parallel  \mathcal{N}_1) = { 1 \over 2 } \left( \mathrm{tr} \left( \Sigma_1^{-1} \Sigma_0 \right) + \left( \mu_1 - \mu_0\right)^\top \Sigma_1^{-1} ( \mu_1 - \mu_0 ) - k + \ln \left( { \det \Sigma_1 \over \det \Sigma_0  } \right)  \right).$$

# %% [markdown]
# Упростите данное выражение для случая, которое используется в VAE, когда компоненты векторов независимы, т.е. матрицы ковариации диагональны. Также упростите выражение, когда второе распределение $\mathcal{N}_1$ является стандартным, т.е. с нулевыми средними и единичными дисперсиями.

# %% [markdown]
# ### Загрузка данных MNIST

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import  torch.nn.functional as F
from matplotlib import pyplot as plt
import numpy as np



# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters 
INPUT_SIZE = 784
BATCH_SIZE = 100

# MNIST dataset 
train_dataset = torchvision.datasets.MNIST(root='../../data', 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='../../data', 
                                          train=False, 
                                          transform=transforms.ToTensor())

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=BATCH_SIZE, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=1000, 
                                          shuffle=False)

# %% [markdown]
# ## MNIST автоенкодер

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, latent_size, hidden_size=100):
        super().__init__()
        self.input_size = input_size
        self.latent_size = latent_size
        self.hidden_size = hidden_size
        self.model = nn.Sequential(nn.Linear(input_size, hidden_size), 
                                   nn.ReLU(), 
                                   nn.Linear(hidden_size, latent_size)
                                  )
    def forward(self, X):
        return self.model(X)

class Decoder(nn.Module):
    def __init__(self,  input_size, latent_size, hidden_size=100):
        super().__init__()
        self.input_size = input_size
        self.latent_size = latent_size
        self.hidden_size = hidden_size
        self.model = nn.Sequential(nn.Linear(latent_size, hidden_size),
                                   nn.ReLU(), 
                                   nn.Linear(hidden_size, input_size)
                                  )
    def forward(self, X):
        return self.model(X)
    
class Autoencoder(nn.Module):
    def __init__(self, input_size, latent_size, hidden_size=100):
        super().__init__()
        self.input_size = input_size
        self.latent_size = latent_size
        self.hidden_size = hidden_size
        self.encoder = Encoder(input_size, latent_size, hidden_size)
        self.decoder = Decoder(input_size, latent_size, hidden_size)
        
    def forward(self, X):
        latent = self.encoder(X)
        return self.decoder(latent)

# %%
model1 = Autoencoder(input_size=INPUT_SIZE, latent_size=2)

# loss
criterion = nn.MSELoss()

# optimizer
optimizer = torch.optim.Adam(model1.parameters(), lr=0.001)  

# Train the model
num_epochs = 30
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        # Move tensors to the configured device
        images = images.reshape(-1, 28 * 28).to(device)
        labels = images
        #labels = labels.to(device)
        
        # Forward pass
        outputs = model1(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
# torch.save(model.state_dict(), 'model.ckpt')
# Out:
# Epoch [1/30], Step [100/600], Loss: 0.0561
# Epoch [1/30], Step [200/600], Loss: 0.0526
# Epoch [1/30], Step [300/600], Loss: 0.0479
# Epoch [1/30], Step [400/600], Loss: 0.0464
# Epoch [1/30], Step [500/600], Loss: 0.0486
# Epoch [1/30], Step [600/600], Loss: 0.0509
# Epoch [2/30], Step [100/600], Loss: 0.0458
# Epoch [2/30], Step [200/600], Loss: 0.0467
# Epoch [2/30], Step [300/600], Loss: 0.0444
# Epoch [2/30], Step [400/600], Loss: 0.0458
# Epoch [2/30], Step [500/600], Loss: 0.0488
# Epoch [2/30], Step [600/600], Loss: 0.0423
# Epoch [3/30], Step [100/600], Loss: 0.0437
# Epoch [3/30], Step [200/600], Loss: 0.0489
# Epoch [3/30], Step [300/600], Loss: 0.0460
# Epoch [3/30], Step [400/600], Loss: 0.0454
# Epoch [3/30], Step [500/600], Loss: 0.0456
# Epoch [3/30], Step [600/600], Loss: 0.0453
# Epoch [4/30], Step [100/600], Loss: 0.0441
# Epoch [4/30], Step [200/600], Loss: 0.0472
# Epoch [4/30], Step [300/600], Loss: 0.0448
# Epoch [4/30], Step [400/600], Loss: 0.0420
# Epoch [4/30], Step [500/600], Loss: 0.0447
# Epoch [4/30], Step [600/600], Loss: 0.0439
# Epoch [5/30], Step [100/600], Loss: 0.0459
# Epoch [5/30], Step [200/600], Loss: 0.0445
# Epoch [5/30], Step [300/600], Loss: 0.0453
# Epoch [5/30], Step [400/600], Loss: 0.0470
# Epoch [5/30], Step [500/600], Loss: 0.0406
# Epoch [5/30], Step [600/600], Loss: 0.0449
# Epoch [6/30], Step [100/600], Loss: 0.0482
# Epoch [6/30], Step [200/600], Loss: 0.0433
# Epoch [6/30], Step [300/600], Loss: 0.0435
# Epoch [6/30], Step [400/600], Loss: 0.0434
# Epoch [6/30], Step [500/600], Loss: 0.0454
# Epoch [6/30], Step [600/600], Loss: 0.0455
# Epoch [7/30], Step [100/600], Loss: 0.0470
# Epoch [7/30], Step [200/600], Loss: 0.0428
# Epoch [7/30], Step [300/600], Loss: 0.0445
# Epoch [7/30], Step [400/600], Loss: 0.0433
# Epoch [7/30], Step [500/600], Loss: 0.0423
# Epoch [7/30], Step [600/600], Loss: 0.0430
# Epoch [8/30], Step [100/600], Loss: 0.0427
# Epoch [8/30], Step [200/600], Loss: 0.0463
# Epoch [8/30], Step [300/600], Loss: 0.0436
# Epoch [8/30], Step [400/600], Loss: 0.0407
# Epoch [8/30], Step [500/600], Loss: 0.0470
# Epoch [8/30], Step [600/600], Loss: 0.0455
# Epoch [9/30], Step [100/600], Loss: 0.0411
# Epoch [9/30], Step [200/600], Loss: 0.0459
# Epoch [9/30], Step [300/600], Loss: 0.0439
# Epoch [9/30], Step [400/600], Loss: 0.0401
# Epoch [9/30], Step [500/600], Loss: 0.0463
# Epoch [9/30], Step [600/600], Loss: 0.0446
# Epoch [10/30], Step [100/600], Loss: 0.0430
# Epoch [10/30], Step [200/600], Loss: 0.0437
# Epoch [10/30], Step [300/600], Loss: 0.0425
# Epoch [10/30], Step [400/600], Loss: 0.0444
# Epoch [10/30], Step [500/600], Loss: 0.0426
# Epoch [10/30], Step [600/600], Loss: 0.0415
# Epoch [11/30], Step [100/600], Loss: 0.0455
# Epoch [11/30], Step [200/600], Loss: 0.0430
# Epoch [11/30], Step [300/600], Loss: 0.0395
# Epoch [11/30], Step [400/600], Loss: 0.0430
# Epoch [11/30], Step [500/600], Loss: 0.0403
# Epoch [11/30], Step [600/600], Loss: 0.0406
# Epoch [12/30], Step [100/600], Loss: 0.0430
# Epoch [12/30], Step [200/600], Loss: 0.0419
# Epoch [12/30], Step [300/600], Loss: 0.0438
# Epoch [12/30], Step [400/600], Loss: 0.0441
# Epoch [12/30], Step [500/600], Loss: 0.0426
# Epoch [12/30], Step [600/600], Loss: 0.0401
# Epoch [13/30], Step [100/600], Loss: 0.0401
# Epoch [13/30], Step [200/600], Loss: 0.0427
# Epoch [13/30], Step [300/600], Loss: 0.0399
# Epoch [13/30], Step [400/600], Loss: 0.0410
# Epoch [13/30], Step [500/600], Loss: 0.0412
# Epoch [13/30], Step [600/600], Loss: 0.0433
# Epoch [14/30], Step [100/600], Loss: 0.0409
# Epoch [14/30], Step [200/600], Loss: 0.0415
# Epoch [14/30], Step [300/600], Loss: 0.0415
# Epoch [14/30], Step [400/600], Loss: 0.0436
# Epoch [14/30], Step [500/600], Loss: 0.0422
# Epoch [14/30], Step [600/600], Loss: 0.0423
# Epoch [15/30], Step [100/600], Loss: 0.0412
# Epoch [15/30], Step [200/600], Loss: 0.0439
# Epoch [15/30], Step [300/600], Loss: 0.0437
# Epoch [15/30], Step [400/600], Loss: 0.0386
# Epoch [15/30], Step [500/600], Loss: 0.0410
# Epoch [15/30], Step [600/600], Loss: 0.0421
# Epoch [16/30], Step [100/600], Loss: 0.0420
# Epoch [16/30], Step [200/600], Loss: 0.0440
# Epoch [16/30], Step [300/600], Loss: 0.0406
# Epoch [16/30], Step [400/600], Loss: 0.0422
# Epoch [16/30], Step [500/600], Loss: 0.0431
# Epoch [16/30], Step [600/600], Loss: 0.0442
# Epoch [17/30], Step [100/600], Loss: 0.0397
# Epoch [17/30], Step [200/600], Loss: 0.0424
# Epoch [17/30], Step [300/600], Loss: 0.0425
# Epoch [17/30], Step [400/600], Loss: 0.0395
# Epoch [17/30], Step [500/600], Loss: 0.0434
# Epoch [17/30], Step [600/600], Loss: 0.0440
# Epoch [18/30], Step [100/600], Loss: 0.0413
# Epoch [18/30], Step [200/600], Loss: 0.0389
# Epoch [18/30], Step [300/600], Loss: 0.0391
# Epoch [18/30], Step [400/600], Loss: 0.0410
# Epoch [18/30], Step [500/600], Loss: 0.0410
# Epoch [18/30], Step [600/600], Loss: 0.0446
# Epoch [19/30], Step [100/600], Loss: 0.0387
# Epoch [19/30], Step [200/600], Loss: 0.0409
# Epoch [19/30], Step [300/600], Loss: 0.0437
# Epoch [19/30], Step [400/600], Loss: 0.0423
# Epoch [19/30], Step [500/600], Loss: 0.0394
# Epoch [19/30], Step [600/600], Loss: 0.0389
# Epoch [20/30], Step [100/600], Loss: 0.0414
# Epoch [20/30], Step [200/600], Loss: 0.0394
# Epoch [20/30], Step [300/600], Loss: 0.0419
# Epoch [20/30], Step [400/600], Loss: 0.0421
# Epoch [20/30], Step [500/600], Loss: 0.0422
# Epoch [20/30], Step [600/600], Loss: 0.0393
# Epoch [21/30], Step [100/600], Loss: 0.0422
# Epoch [21/30], Step [200/600], Loss: 0.0438
# Epoch [21/30], Step [300/600], Loss: 0.0419
# Epoch [21/30], Step [400/600], Loss: 0.0385
# Epoch [21/30], Step [500/600], Loss: 0.0424
# Epoch [21/30], Step [600/600], Loss: 0.0431
# Epoch [22/30], Step [100/600], Loss: 0.0413
# Epoch [22/30], Step [200/600], Loss: 0.0413
# Epoch [22/30], Step [300/600], Loss: 0.0411
# Epoch [22/30], Step [400/600], Loss: 0.0409
# Epoch [22/30], Step [500/600], Loss: 0.0437
# Epoch [22/30], Step [600/600], Loss: 0.0399
# Epoch [23/30], Step [100/600], Loss: 0.0423
# Epoch [23/30], Step [200/600], Loss: 0.0412
# Epoch [23/30], Step [300/600], Loss: 0.0393
# Epoch [23/30], Step [400/600], Loss: 0.0410
# Epoch [23/30], Step [500/600], Loss: 0.0424
# Epoch [23/30], Step [600/600], Loss: 0.0428
# Epoch [24/30], Step [100/600], Loss: 0.0456
# Epoch [24/30], Step [200/600], Loss: 0.0414
# Epoch [24/30], Step [300/600], Loss: 0.0431
# Epoch [24/30], Step [400/600], Loss: 0.0422
# Epoch [24/30], Step [500/600], Loss: 0.0418
# Epoch [24/30], Step [600/600], Loss: 0.0431
# Epoch [25/30], Step [100/600], Loss: 0.0397
# Epoch [25/30], Step [200/600], Loss: 0.0411
# Epoch [25/30], Step [300/600], Loss: 0.0409
# Epoch [25/30], Step [400/600], Loss: 0.0426
# Epoch [25/30], Step [500/600], Loss: 0.0404
# Epoch [25/30], Step [600/600], Loss: 0.0393
# Epoch [26/30], Step [100/600], Loss: 0.0409
# Epoch [26/30], Step [200/600], Loss: 0.0412
# Epoch [26/30], Step [300/600], Loss: 0.0403
# Epoch [26/30], Step [400/600], Loss: 0.0413
# Epoch [26/30], Step [500/600], Loss: 0.0414
# Epoch [26/30], Step [600/600], Loss: 0.0389
# Epoch [27/30], Step [100/600], Loss: 0.0415
# Epoch [27/30], Step [200/600], Loss: 0.0415
# Epoch [27/30], Step [300/600], Loss: 0.0395
# Epoch [27/30], Step [400/600], Loss: 0.0417
# Epoch [27/30], Step [500/600], Loss: 0.0425
# Epoch [27/30], Step [600/600], Loss: 0.0430
# Epoch [28/30], Step [100/600], Loss: 0.0395
# Epoch [28/30], Step [200/600], Loss: 0.0404
# Epoch [28/30], Step [300/600], Loss: 0.0431
# Epoch [28/30], Step [400/600], Loss: 0.0389
# Epoch [28/30], Step [500/600], Loss: 0.0415
# Epoch [28/30], Step [600/600], Loss: 0.0419
# Epoch [29/30], Step [100/600], Loss: 0.0418
# Epoch [29/30], Step [200/600], Loss: 0.0413
# Epoch [29/30], Step [300/600], Loss: 0.0406
# Epoch [29/30], Step [400/600], Loss: 0.0410
# Epoch [29/30], Step [500/600], Loss: 0.0407
# Epoch [29/30], Step [600/600], Loss: 0.0406
# Epoch [30/30], Step [100/600], Loss: 0.0382
# Epoch [30/30], Step [200/600], Loss: 0.0391
# Epoch [30/30], Step [300/600], Loss: 0.0419
# Epoch [30/30], Step [400/600], Loss: 0.0367
# Epoch [30/30], Step [500/600], Loss: 0.0394
# Epoch [30/30], Step [600/600], Loss: 0.0431

# %%
for (images, labels) in train_loader:
    break
images = images.reshape(-1, 28 * 28).to(device)
output = model1(images)

orig_img = images[0].detach().numpy().reshape(28, 28)
img = output[0].detach().numpy().reshape(28, 28)
fig, axs = plt.subplots(1, 2, figsize=(6, 12))
axs[0].imshow(orig_img, cmap='gray')
axs[1].imshow(img, cmap='gray')
plt.show()
print(labels[0])

# fig, axs = plt.subplots(1, 2)#, figsize=(12, 6))
# axs[0].hist(orig_img.flatten(), bins=25)
# axs[1].hist(img.flatten(), bins=25)
# plt.show()

for (images, labels) in test_loader:
    break
images = images.reshape(-1, 28 * 28).to(device)
latent = model1.encoder(images)
latent_pepr = latent.detach().numpy()
plt.scatter(latent_pepr[:,0], latent_pepr[:,1], c=labels, cmap='tab10')
plt.colorbar()
plt.show()
# Out:
# tensor(6)

# %% [markdown]
# ## Регуляризация автоенкодера

# %%
class Autoencoder_latent(nn.Module):
    def __init__(self, input_size, latent_size, hidden_size=100):
        super().__init__()
        self.input_size = input_size
        self.latent_size = latent_size
        self.hidden_size = hidden_size
        self.encoder = Encoder(input_size, latent_size, hidden_size)
        self.decoder = Decoder(input_size, latent_size, hidden_size)
        
    def forward(self, X):
        latent = self.encoder(X)
        return self.decoder(latent), latent

# %%
model2 = Autoencoder_latent(input_size=INPUT_SIZE, latent_size=2)

# loss
criterion = nn.MSELoss()

# optimizer
optimizer = torch.optim.Adam(model2.parameters(), lr=0.001)  
LAMBDA = 0.1
# Train the model
num_epochs = 500
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        # Move tensors to the configured device
        images = images.reshape(-1, 28 * 28).to(device)
        labels = images
        #labels = labels.to(device)
        
        # Forward pass
        outputs, latent = model2(images)
        reconstruction_loss = criterion(outputs, labels)
        regulizer_loss = (latent * latent).sum(axis=1).mean()
        
        loss = reconstruction_loss + LAMBDA/2 * regulizer_loss
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], reconstruction_loss:{:.6f}, regulizer_loss:{:.6f}, Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, 
                           reconstruction_loss.item(), regulizer_loss.item(), loss.item()))
# Out:
# Epoch [1/500], Step [100/600], reconstruction_loss:0.067377, regulizer_loss:0.017860, Loss: 0.0683
# Epoch [1/500], Step [200/600], reconstruction_loss:0.059648, regulizer_loss:0.033537, Loss: 0.0613
# Epoch [1/500], Step [300/600], reconstruction_loss:0.055887, regulizer_loss:0.018452, Loss: 0.0568
# Epoch [1/500], Step [400/600], reconstruction_loss:0.055377, regulizer_loss:0.018792, Loss: 0.0563
# Epoch [1/500], Step [500/600], reconstruction_loss:0.055705, regulizer_loss:0.014152, Loss: 0.0564
# Epoch [1/500], Step [600/600], reconstruction_loss:0.053807, regulizer_loss:0.018155, Loss: 0.0547
# Epoch [2/500], Step [100/600], reconstruction_loss:0.055841, regulizer_loss:0.016188, Loss: 0.0566
# Epoch [2/500], Step [200/600], reconstruction_loss:0.052402, regulizer_loss:0.015685, Loss: 0.0532
# Epoch [2/500], Step [300/600], reconstruction_loss:0.052127, regulizer_loss:0.013371, Loss: 0.0528
# Epoch [2/500], Step [400/600], reconstruction_loss:0.051273, regulizer_loss:0.013634, Loss: 0.0520
# Epoch [2/500], Step [500/600], reconstruction_loss:0.049894, regulizer_loss:0.012895, Loss: 0.0505
# Epoch [2/500], Step [600/600], reconstruction_loss:0.053609, regulizer_loss:0.011902, Loss: 0.0542
# Epoch [3/500], Step [100/600], reconstruction_loss:0.052979, regulizer_loss:0.011877, Loss: 0.0536
# Epoch [3/500], Step [200/600], reconstruction_loss:0.054962, regulizer_loss:0.014151, Loss: 0.0557
# Epoch [3/500], Step [300/600], reconstruction_loss:0.051324, regulizer_loss:0.014299, Loss: 0.0520
# Epoch [3/500], Step [400/600], reconstruction_loss:0.050634, regulizer_loss:0.012874, Loss: 0.0513
# Epoch [3/500], Step [500/600], reconstruction_loss:0.049679, regulizer_loss:0.011085, Loss: 0.0502
# Epoch [3/500], Step [600/600], reconstruction_loss:0.049852, regulizer_loss:0.010599, Loss: 0.0504
# Epoch [4/500], Step [100/600], reconstruction_loss:0.053301, regulizer_loss:0.010555, Loss: 0.0538
# Epoch [4/500], Step [200/600], reconstruction_loss:0.048046, regulizer_loss:0.009029, Loss: 0.0485
# Epoch [4/500], Step [300/600], reconstruction_loss:0.050273, regulizer_loss:0.010055, Loss: 0.0508
# Epoch [4/500], Step [400/600], reconstruction_loss:0.050228, regulizer_loss:0.009965, Loss: 0.0507
# Epoch [4/500], Step [500/600], reconstruction_loss:0.052972, regulizer_loss:0.008135, Loss: 0.0534
# Epoch [4/500], Step [600/600], reconstruction_loss:0.052697, regulizer_loss:0.009346, Loss: 0.0532
# Epoch [5/500], Step [100/600], reconstruction_loss:0.051608, regulizer_loss:0.008764, Loss: 0.0520
# Epoch [5/500], Step [200/600], reconstruction_loss:0.051488, regulizer_loss:0.009447, Loss: 0.0520
# Epoch [5/500], Step [300/600], reconstruction_loss:0.050373, regulizer_loss:0.009083, Loss: 0.0508
# Epoch [5/500], Step [400/600], reconstruction_loss:0.046822, regulizer_loss:0.009636, Loss: 0.0473
# Epoch [5/500], Step [500/600], reconstruction_loss:0.052108, regulizer_loss:0.009229, Loss: 0.0526
# Epoch [5/500], Step [600/600], reconstruction_loss:0.050545, regulizer_loss:0.008823, Loss: 0.0510
# Epoch [6/500], Step [100/600], reconstruction_loss:0.049259, regulizer_loss:0.008940, Loss: 0.0497
# Epoch [6/500], Step [200/600], reconstruction_loss:0.047031, regulizer_loss:0.008766, Loss: 0.0475
# Epoch [6/500], Step [300/600], reconstruction_loss:0.050444, regulizer_loss:0.007661, Loss: 0.0508
# Epoch [6/500], Step [400/600], reconstruction_loss:0.055172, regulizer_loss:0.008320, Loss: 0.0556
# Epoch [6/500], Step [500/600], reconstruction_loss:0.048072, regulizer_loss:0.008466, Loss: 0.0485
# Epoch [6/500], Step [600/600], reconstruction_loss:0.049361, regulizer_loss:0.008495, Loss: 0.0498
# Epoch [7/500], Step [100/600], reconstruction_loss:0.053238, regulizer_loss:0.007618, Loss: 0.0536
# Epoch [7/500], Step [200/600], reconstruction_loss:0.050623, regulizer_loss:0.007554, Loss: 0.0510
# Epoch [7/500], Step [300/600], reconstruction_loss:0.048844, regulizer_loss:0.008583, Loss: 0.0493
# Epoch [7/500], Step [400/600], reconstruction_loss:0.048107, regulizer_loss:0.008251, Loss: 0.0485
# Epoch [7/500], Step [500/600], reconstruction_loss:0.049850, regulizer_loss:0.009209, Loss: 0.0503
# Epoch [7/500], Step [600/600], reconstruction_loss:0.047931, regulizer_loss:0.009206, Loss: 0.0484
# Epoch [8/500], Step [100/600], reconstruction_loss:0.052436, regulizer_loss:0.007298, Loss: 0.0528
# Epoch [8/500], Step [200/600], reconstruction_loss:0.047821, regulizer_loss:0.009042, Loss: 0.0483
# Epoch [8/500], Step [300/600], reconstruction_loss:0.048758, regulizer_loss:0.009140, Loss: 0.0492
# Epoch [8/500], Step [400/600], reconstruction_loss:0.052076, regulizer_loss:0.008958, Loss: 0.0525
# Epoch [8/500], Step [500/600], reconstruction_loss:0.049648, regulizer_loss:0.008520, Loss: 0.0501
# Epoch [8/500], Step [600/600], reconstruction_loss:0.047643, regulizer_loss:0.010676, Loss: 0.0482
# Epoch [9/500], Step [100/600], reconstruction_loss:0.049960, regulizer_loss:0.009296, Loss: 0.0504
# Epoch [9/500], Step [200/600], reconstruction_loss:0.044678, regulizer_loss:0.011363, Loss: 0.0452
# Epoch [9/500], Step [300/600], reconstruction_loss:0.048699, regulizer_loss:0.008829, Loss: 0.0491
# Epoch [9/500], Step [400/600], reconstruction_loss:0.046151, regulizer_loss:0.010032, Loss: 0.0467
# Epoch [9/500], Step [500/600], reconstruction_loss:0.051664, regulizer_loss:0.009156, Loss: 0.0521
# Epoch [9/500], Step [600/600], reconstruction_loss:0.050819, regulizer_loss:0.009551, Loss: 0.0513
# Epoch [10/500], Step [100/600], reconstruction_loss:0.045312, regulizer_loss:0.012245, Loss: 0.0459
# Epoch [10/500], Step [200/600], reconstruction_loss:0.052074, regulizer_loss:0.010758, Loss: 0.0526
# Epoch [10/500], Step [300/600], reconstruction_loss:0.048753, regulizer_loss:0.009701, Loss: 0.0492
# Epoch [10/500], Step [400/600], reconstruction_loss:0.048771, regulizer_loss:0.010124, Loss: 0.0493
# Epoch [10/500], Step [500/600], reconstruction_loss:0.047077, regulizer_loss:0.010534, Loss: 0.0476
# Epoch [10/500], Step [600/600], reconstruction_loss:0.051607, regulizer_loss:0.010438, Loss: 0.0521
# Epoch [11/500], Step [100/600], reconstruction_loss:0.048582, regulizer_loss:0.010960, Loss: 0.0491
# Epoch [11/500], Step [200/600], reconstruction_loss:0.047655, regulizer_loss:0.010703, Loss: 0.0482
# Epoch [11/500], Step [300/600], reconstruction_loss:0.049602, regulizer_loss:0.010860, Loss: 0.0501
# Epoch [11/500], Step [400/600], reconstruction_loss:0.048271, regulizer_loss:0.010877, Loss: 0.0488
# Epoch [11/500], Step [500/600], reconstruction_loss:0.048397, regulizer_loss:0.010548, Loss: 0.0489
# Epoch [11/500], Step [600/600], reconstruction_loss:0.048199, regulizer_loss:0.009901, Loss: 0.0487
# Epoch [12/500], Step [100/600], reconstruction_loss:0.047534, regulizer_loss:0.010790, Loss: 0.0481
# Epoch [12/500], Step [200/600], reconstruction_loss:0.047914, regulizer_loss:0.010258, Loss: 0.0484
# Epoch [12/500], Step [300/600], reconstruction_loss:0.046322, regulizer_loss:0.011023, Loss: 0.0469
# Epoch [12/500], Step [400/600], reconstruction_loss:0.046347, regulizer_loss:0.009821, Loss: 0.0468
# Epoch [12/500], Step [500/600], reconstruction_loss:0.049570, regulizer_loss:0.009953, Loss: 0.0501
# Epoch [12/500], Step [600/600], reconstruction_loss:0.050032, regulizer_loss:0.010099, Loss: 0.0505
# Epoch [13/500], Step [100/600], reconstruction_loss:0.043675, regulizer_loss:0.011416, Loss: 0.0442
# Epoch [13/500], Step [200/600], reconstruction_loss:0.048225, regulizer_loss:0.011718, Loss: 0.0488
# Epoch [13/500], Step [300/600], reconstruction_loss:0.050405, regulizer_loss:0.010068, Loss: 0.0509
# Epoch [13/500], Step [400/600], reconstruction_loss:0.047539, regulizer_loss:0.010248, Loss: 0.0481
# Epoch [13/500], Step [500/600], reconstruction_loss:0.045068, regulizer_loss:0.011907, Loss: 0.0457
# Epoch [13/500], Step [600/600], reconstruction_loss:0.043977, regulizer_loss:0.010290, Loss: 0.0445
# Epoch [14/500], Step [100/600], reconstruction_loss:0.050159, regulizer_loss:0.011579, Loss: 0.0507
# Epoch [14/500], Step [200/600], reconstruction_loss:0.048468, regulizer_loss:0.011469, Loss: 0.0490
# Epoch [14/500], Step [300/600], reconstruction_loss:0.048198, regulizer_loss:0.009080, Loss: 0.0487
# Epoch [14/500], Step [400/600], reconstruction_loss:0.046038, regulizer_loss:0.010752, Loss: 0.0466
# Epoch [14/500], Step [500/600], reconstruction_loss:0.046599, regulizer_loss:0.010575, Loss: 0.0471
#
# Epoch [14/500], Step [600/600], reconstruction_loss:0.047742, regulizer_loss:0.010439, Loss: 0.0483
# Epoch [15/500], Step [100/600], reconstruction_loss:0.048253, regulizer_loss:0.011489, Loss: 0.0488
# Epoch [15/500], Step [200/600], reconstruction_loss:0.045530, regulizer_loss:0.012738, Loss: 0.0462
# Epoch [15/500], Step [300/600], reconstruction_loss:0.045464, regulizer_loss:0.011539, Loss: 0.0460
# Epoch [15/500], Step [400/600], reconstruction_loss:0.048667, regulizer_loss:0.011568, Loss: 0.0492
# Epoch [15/500], Step [500/600], reconstruction_loss:0.045287, regulizer_loss:0.010900, Loss: 0.0458
# Epoch [15/500], Step [600/600], reconstruction_loss:0.046416, regulizer_loss:0.011471, Loss: 0.0470
# Epoch [16/500], Step [100/600], reconstruction_loss:0.048157, regulizer_loss:0.011926, Loss: 0.0488
# Epoch [16/500], Step [200/600], reconstruction_loss:0.049094, regulizer_loss:0.010452, Loss: 0.0496
# Epoch [16/500], Step [300/600], reconstruction_loss:0.046694, regulizer_loss:0.010327, Loss: 0.0472
# Epoch [16/500], Step [400/600], reconstruction_loss:0.044305, regulizer_loss:0.012277, Loss: 0.0449
# Epoch [16/500], Step [500/600], reconstruction_loss:0.048602, regulizer_loss:0.011772, Loss: 0.0492
# Epoch [16/500], Step [600/600], reconstruction_loss:0.046178, regulizer_loss:0.012178, Loss: 0.0468
# Epoch [17/500], Step [100/600], reconstruction_loss:0.044489, regulizer_loss:0.012110, Loss: 0.0451
# Epoch [17/500], Step [200/600], reconstruction_loss:0.049367, regulizer_loss:0.011507, Loss: 0.0499
# Epoch [17/500], Step [300/600], reconstruction_loss:0.045200, regulizer_loss:0.011993, Loss: 0.0458
# Epoch [17/500], Step [400/600], reconstruction_loss:0.048388, regulizer_loss:0.012398, Loss: 0.0490
# Epoch [17/500], Step [500/600], reconstruction_loss:0.045802, regulizer_loss:0.013228, Loss: 0.0465
# Epoch [17/500], Step [600/600], reconstruction_loss:0.047755, regulizer_loss:0.011076, Loss: 0.0483
# Epoch [18/500], Step [100/600], reconstruction_loss:0.043998, regulizer_loss:0.009225, Loss: 0.0445
# Epoch [18/500], Step [200/600], reconstruction_loss:0.046339, regulizer_loss:0.012130, Loss: 0.0469
# Epoch [18/500], Step [300/600], reconstruction_loss:0.043778, regulizer_loss:0.010990, Loss: 0.0443
# Epoch [18/500], Step [400/600], reconstruction_loss:0.046260, regulizer_loss:0.012269, Loss: 0.0469
# Epoch [18/500], Step [500/600], reconstruction_loss:0.046695, regulizer_loss:0.012622, Loss: 0.0473
# Epoch [18/500], Step [600/600], reconstruction_loss:0.045499, regulizer_loss:0.013842, Loss: 0.0462
# Epoch [19/500], Step [100/600], reconstruction_loss:0.044499, regulizer_loss:0.014538, Loss: 0.0452
# Epoch [19/500], Step [200/600], reconstruction_loss:0.048479, regulizer_loss:0.011304, Loss: 0.0490
# Epoch [19/500], Step [300/600], reconstruction_loss:0.046836, regulizer_loss:0.010469, Loss: 0.0474
# Epoch [19/500], Step [400/600], reconstruction_loss:0.047563, regulizer_loss:0.012820, Loss: 0.0482
# Epoch [19/500], Step [500/600], reconstruction_loss:0.045852, regulizer_loss:0.012447, Loss: 0.0465
# Epoch [19/500], Step [600/600], reconstruction_loss:0.046082, regulizer_loss:0.012696, Loss: 0.0467
# Epoch [20/500], Step [100/600], reconstruction_loss:0.042626, regulizer_loss:0.013643, Loss: 0.0433
# Epoch [20/500], Step [200/600], reconstruction_loss:0.046652, regulizer_loss:0.012485, Loss: 0.0473
# Epoch [20/500], Step [300/600], reconstruction_loss:0.044639, regulizer_loss:0.014176, Loss: 0.0453
# Epoch [20/500], Step [400/600], reconstruction_loss:0.047345, regulizer_loss:0.010494, Loss: 0.0479
# ---------------------------------------------------------------------------
# Traceback (most recent call last)

# %%
for (images, labels) in train_loader:
    break
images = images.reshape(-1, 28 * 28).to(device)
output, latent = model2(images)

orig_img = images[0].detach().numpy().reshape(28, 28)
img = output[0].detach().numpy().reshape(28, 28)
fig, axs = plt.subplots(1, 2, figsize=(6, 12))
axs[0].imshow(orig_img, cmap='gray')
axs[1].imshow(img, cmap='gray')
plt.show()
print(labels[0])

for (images, labels) in test_loader:
    break
images = images.reshape(-1, 28 * 28).to(device)
output, latent = model2(images)
latent_pepr = latent.detach().numpy()
plt.scatter(latent_pepr[:,0], latent_pepr[:,1], c=labels, cmap='tab10')
plt.colorbar()
plt.show()
# Out:
# tensor(9)

# %%
lim = 0.15
xx = np.linspace(-lim, lim, 15)
yy = np.linspace(-lim, lim, 15)
XX, YY = np.meshgrid(xx, yy)
ZZ = np.zeros((XX.size, 2)) #np.concatenate((XX[None], YY[None]), axis=0)
ZZ[:,0] = XX.flatten()
ZZ[:,1] = YY.flatten()

latent_gen = torch.FloatTensor(ZZ).to(device)
output = model2.decoder(latent_gen)

# %%
images = output.detach().numpy()
big_image = np.zeros((15 * 28, 15 * 28))
for i in range(15):
    for j in range(15):
        big_image[i*28 : (i+1)*28, j*28 : (j+1)*28] = 1 - images[15*i + j].reshape(28, 28)

# %%
plt.imshow(big_image, cmap='gray')
plt.show()

# %% [markdown]
# ## VAE автоенкодер

# %%
class VariationalEncoder(nn.Module):
    def __init__(self,input_size, latent_dims, hidden_size = 100):
        super(VariationalEncoder,self).__init__()
        self.linear1 = nn.Linear(input_size,hidden_size)
        self.linear2 = nn.Linear(hidden_size,latent_dims)
        self.linear3 = nn.Linear(hidden_size,latent_dims)

        self.N = torch.distributions.Normal(0,1)
        # self.N.loc = self.N.loc.cuda()
        # self.N.scale = self.N.scale.cuda()
        self.kl = 0
    def forward(self,x):
        # x = torch.flatten(x,start_dim=1)
        x = F.relu(self.linear1(x))
        mu = self.linear2(x)
        sigma = torch.exp(self.linear3(x))

        z = mu + sigma*self.N.sample(mu.shape)
        self.kl = (sigma**2 + mu**2 - torch.log(sigma) -1/2).sum()
        return  z
    
class  VariationalAutoEncoder(nn.Module):
    def __init__(self,input_size, latent_dims,hidden_size = 100):
        super(VariationalAutoEncoder,self).__init__()
        self.encoder = VariationalEncoder(input_size,latent_dims,hidden_size)
        self.decoder = Decoder(input_size,latent_dims, hidden_size)
    
    def forward(self,x):
        z = self.encoder(x)
        return self.decoder(z)

# %%
def train(var_autoencoder, data, epochs=30):
    opt = torch.optim.Adam(var_autoencoder.parameters())
    criterion = nn.MSELoss()
    for epoch in range(epochs):
        i =0
        for x, y in data:
            x = torch.flatten(x,start_dim=1).to(device) # GPU
            opt.zero_grad()
            x_hat = var_autoencoder(x)
            loss = ((x_hat-x)**2).sum() + var_autoencoder.encoder.kl
            # print(criterion(x_hat,x))
            loss.backward()
            opt.step()
            i+=1
        print(f"epoch {epoch} batch number {i} loss = {loss}")
    return var_autoencoder

# %%
vae = VariationalAutoEncoder(INPUT_SIZE,latent_dims=2).to(device) # GPU
vae = train(vae, train_loader)
# Out:
# epoch 0 batch number 600 loss = 4363.4404296875
# epoch 1 batch number 600 loss = 4199.2685546875
# epoch 2 batch number 600 loss = 4340.31591796875
# epoch 3 batch number 600 loss = 4140.72119140625
# epoch 4 batch number 600 loss = 4203.4755859375
# epoch 5 batch number 600 loss = 4068.135986328125
# epoch 6 batch number 600 loss = 3964.73974609375
# epoch 7 batch number 600 loss = 4057.5380859375
# epoch 8 batch number 600 loss = 4278.72607421875
# epoch 9 batch number 600 loss = 3949.81005859375
# epoch 10 batch number 600 loss = 4061.228759765625
# epoch 11 batch number 600 loss = 4065.233154296875
# epoch 12 batch number 600 loss = 4249.8388671875
# epoch 13 batch number 600 loss = 3836.685791015625
# epoch 14 batch number 600 loss = 3885.054931640625
# epoch 15 batch number 600 loss = 4009.508056640625
# epoch 16 batch number 600 loss = 3949.552001953125
# epoch 17 batch number 600 loss = 3970.89208984375
# epoch 18 batch number 600 loss = 4113.5087890625
# epoch 19 batch number 600 loss = 4147.56005859375
# epoch 20 batch number 600 loss = 4025.303466796875
# epoch 21 batch number 600 loss = 3764.737060546875
# epoch 22 batch number 600 loss = 4176.39794921875
# epoch 23 batch number 600 loss = 3936.266845703125
# epoch 24 batch number 600 loss = 3767.800537109375
# epoch 25 batch number 600 loss = 3833.287353515625
# epoch 26 batch number 600 loss = 3828.33251953125
# epoch 27 batch number 600 loss = 3697.341064453125
# epoch 28 batch number 600 loss = 3732.06787109375
# epoch 29 batch number 600 loss = 3719.551513671875

# %%
def plot_latent(autoencoder,data,num_batches=100):
    for i ,(x, y) in enumerate(data):
        z = autoencoder.encoder(torch.flatten(x,start_dim=1).to(device))
        z = z.to('cpu').detach().numpy()
        plt.scatter(z[:, 0], z[:, 1], c=y, cmap='tab10')
        if i > num_batches:
            plt.colorbar()
            break

# %%
plot_latent(vae,train_loader)

# %%
def plot_reconstructed(autoencoder, r0=(-5, 10), r1=(-10, 5), n=12):
    w = 28
    img = np.zeros((n*w,n*w))
    for i,y  in enumerate(np.linspace(*r1, n)):
        for j, x in enumerate(np.linspace(*r0, n)):
            z = torch.Tensor([[x, y]]).to(device)
            x_hat = autoencoder.decoder(z)
            x_hat = x_hat.reshape(28, 28).to('cpu').detach().numpy()
            img[(n-1-i)*w:(n-1-i+1)*w, j*w:(j+1)*w] = x_hat
    plt.imshow(img, extent=[*r0, *r1])

# %%
plot_reconstructed(vae)
